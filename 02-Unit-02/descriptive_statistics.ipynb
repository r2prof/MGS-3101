# %% [markdown]
# #### Descriptive Statistics with Python Project

# %% [markdown]
# #### Dataset web address
# https://raw.githubusercontent.com/r2prof/Data/refs/heads/main/iris.csv

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import dataset

# %%
# To import dataset in Visual Code Studio
# df = pd.read_csv('iris.csv')

# %%
# To import dataset in Google Colab
# url = 'https://raw.githubusercontent.com/r2prof/MGS-3101/main/iris.csv'

url = 'https://raw.githubusercontent.com/r2prof/Data/refs/heads/main/iris.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# #### Summary statistics of numerical columns

# %%
df.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
# Summary statistics of character columns
df.describe(include=['object']).T
# Out:
#         count unique          top freq
# Species   150      3  Iris-setosa   50

# %%
df.describe(include='all').T
# Out:
#                count unique          top freq      mean        std  min  \
# Id             150.0    NaN          NaN  NaN      75.5  43.445368  1.0
# SepalLengthCm  150.0    NaN          NaN  NaN  5.843333   0.828066  4.3
# SepalWidthCm   150.0    NaN          NaN  NaN     3.054   0.433594  2.0
# PetalLengthCm  150.0    NaN          NaN  NaN  3.758667    1.76442  1.0
# PetalWidthCm   150.0    NaN          NaN  NaN  1.198667   0.763161  0.1
# Species          150      3  Iris-setosa   50       NaN        NaN  NaN
#
#                  25%   50%     75%    max
# Id             38.25  75.5  112.75  150.0
# SepalLengthCm    5.1   5.8     6.4    7.9
# SepalWidthCm     2.8   3.0     3.3    4.4
# PetalLengthCm    1.6  4.35     5.1    6.9
# PetalWidthCm     0.3   1.3     1.8    2.5
# Species          NaN   NaN     NaN    NaN

# %%
mean = df['SepalLengthCm'].mean()
print(mean)
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
median = df['SepalLengthCm'].median()
print(median)
# Out:
# 5.8

# %%
mode = df['SepalLengthCm'].mode()
print(mode)
# Out:
# 0    5.0
# Name: SepalLengthCm, dtype: float64

# %%
# Select rows using a condition
df[df['SepalLengthCm'] > 5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 5       Iris-setosa
# 10      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# ..              ...
# ...

# %%
# Plot the distribution using sns.histplot with KDE
data = df['SepalLengthCm']
sns.histplot(data, bins=10, kde=True, label='Sepal Length (cm)')
plt.legend()
plt.show()

# %%
min_value = df['SepalLengthCm'].min()
print(min_value)
# Out:
# 4.3

# %%
max_value = df['SepalLengthCm'].max()
print(max_value)
# Out:
# 7.9

# %%
sl_range = df['SepalLengthCm'].max() - df['SepalLengthCm'].min()
print(sl_range)
# Out:
# 3.6000000000000005

# %%
sl_var = df['SepalLengthCm'].var()
print(sl_var)
# Out:
# 0.6856935123042507

# %%
sl_std = df['SepalLengthCm'].std()
# sl_std
print(sl_std)
# Out:
# 0.828066127977863

# %%
Q2 = df['SepalLengthCm'].quantile(0.5)
print(Q2)
# Out:
# 5.8

# %%
Q3 = df['SepalLengthCm'].quantile(0.75)
print(Q3)
# Out:
# 6.4

# %%
Q1 = df['SepalLengthCm'].quantile(0.25)
print(Q1)
# Out:
# 5.1

# %%
IQR = Q3  - Q1
print(IQR)
# Out:
# 1.3000000000000007

# %%
plt.boxplot(df['SepalLengthCm']);
# plt.show()

# %%
# Skewness
# Skewness is a statistical measure that quantifies the degree of asymmetry in the 
# distribution of a dataset. It indicates whether the data points are more concentrated 
# on one side of the mean compared to the other.

sl_sk = df['SepalLengthCm'].skew()
print(sl_sk)
# Out:
# 0.3149109566369728

# %%
# Kurtosis
# Kurtosis is a statistical measure that quantifies the shape of the tails of a 
# probability distribution relative to its peak. It indicates whether the data 
# distribution has heavier or lighter tails compared to a normal distribution, 
# providing insights into the propensity for extreme values (outliers).

sl_kur = df['SepalLengthCm'].kurt()
print(sl_kur)
# Out:
# -0.5520640413156395
